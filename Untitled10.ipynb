# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import numpy as np

# %%
dt=pd.read_csv("data.csv")

# %%
dt
# Out:
#    student_id  age  gender          state  city_tier  college_tier  \
# 0    STU00001   22    Male      Karnataka          1             2
# 1    STU00002   20    Male     Tamil Nadu          2             3
# 2    STU00003   23  Female  Uttar Pradesh          3             2
# 3    STU00004   25    Male    Maharashtra          2             3
# 4    STU00005   25  Female    West Bengal          3             3
# 5    STU00006   24    Male  Uttar Pradesh          3             3
# 6    STU00007   20  Female      Karnataka          2             3
# 7    STU00008   24  Female        Gujarat          2             3
# 8    STU00009   20    Male      Karnataka          2             3
# 9    STU00010   23    Male          Delhi          3             3
# 10   STU00011   21    Male      Karnataka          2             2
# 11   STU00012   24    Male      Telangana          1             3
# 12   STU00013   20    Male        Gujarat          2             2
# ...

# %%
dt.columns
# Out:
# Index(['student_id', 'age', 'gender', 'state', 'city_tier', 'college_tier',
#        'branch', 'degree', 'cgpa', 'backlog_history', 'attendance_percentage',
#        'primary_language', 'DSA_problems_solved', 'GitHub_repos',
#        'hackathons_participated', 'adaptability_score'],
#       dtype='object')

# %%
dt.shape
# Out:
# (19, 16)

# %%
dt.describe()
# Out:
#              age  city_tier  college_tier       cgpa  backlog_history  \
# count  19.000000  19.000000     19.000000  19.000000        19.000000
# mean   22.736842   2.210526      2.578947   7.286316         0.736842
# std     1.851189   0.787327      0.692483   1.007843         1.097578
# min    20.000000   1.000000      1.000000   5.980000         0.000000
# 25%    21.500000   2.000000      2.000000   6.670000         0.000000
# 50%    23.000000   2.000000      3.000000   7.110000         0.000000
# 75%    24.000000   3.000000      3.000000   7.715000         1.500000
# max    25.000000   3.000000      3.000000   9.900000         3.000000
#
#        attendance_percentage  DSA_problems_solved  GitHub_repos  \
# count              19.000000            19.000000     19.000000
# mean               79.300000           680.263158     15.736842
# std                10.519347           134.128811      7.922136
# min                62.600000           490.000000      3.000000
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               19 non-null     object
#  1   age                      19 non-null     int64
#  2   gender                   19 non-null     object
#  3   state                    19 non-null     object
#  4   city_tier                19 non-null     int64
#  5   college_tier             19 non-null     int64
#  6   branch                   19 non-null     object
#  7   degree                   19 non-null     object
#  8   cgpa                     19 non-null     float64
#  9   backlog_history          19 non-null     int64
#  10  attendance_percentage    19 non-null     float64
#  11  primary_language         19 non-null     object
#  12  DSA_problems_solved      19 non-null     int64
#  13  GitHub_repos             19 non-null     int64
# ...

# %%
dt.isnull().sum()
# Out:
# student_id                 0
# age                        0
# gender                     0
# state                      0
# city_tier                  0
# college_tier               0
# branch                     0
# degree                     0
# cgpa                       0
# backlog_history            0
# attendance_percentage      0
# primary_language           0
# DSA_problems_solved        0
# GitHub_repos               0
# hackathons_participated    0
# adaptability_score         0
# dtype: int64

# %%
dt.duplicated().sum()
# Out:
# np.int64(0)

# %%
dt["hackathons_participated"].max()
# Out:
# 5

# %%
dt["hackathons_participated"].min()
# Out:
# 0

# %%
plt.plot(dt["cgpa"],dt["adaptability_score"])

# %%
plt.title("Student Placement Record")
plt.xlabel("Hackathons Participated")
plt.ylabel("No of students participated")
# Out:
# Text(0, 0.5, 'No of students participated')

# %%
dt["hackathons_participated"].value_counts().plot(kind='line')
plt.show()

# %%
dt["hackathons_participated"].value_counts().plot(kind='bar')
plt.show()

# %%
dt["hackathons_participated"].value_counts().plot(kind='pie')
plt.show()
